# %%
import pandas as pd
import requests

# %%
requests.get('https://aerodatabox.p.rapidapi.com/health/services/feeds/FlightSchedules/airports')
# Out:
# <Response [401]>

# %%
response = requests.get('https://aerodatabox.p.rapidapi.com/health/services/feeds/FlightSchedules/airports')

# %%
response.json()
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/airports/iata/DME"

headers = {
	"X-RapidAPI-Key": "1400d8f71dmsha12222371ce4d06p16c339jsnff0f8c9a8dcc",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

response.json()['icao']
# Out:
# 'UUDD'

# %%
data=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c5bc87518260a2911807fb0ab754193d&language=en-US&page=1')

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 44.097,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-19',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 3761},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
import pandas
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c5bc87518260a2911807fb0ab754193d&language=en-US&page=1')

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                                          title  \
# 0    19404                    Dilwale Dulhania Le Jayenge
# 1      278                       The Shawshank Redemption
# 2      238                                  The Godfather
# 3      424                               Schindler's List
# 4      240                         The Godfather: Part II
# 5   667257                              Impossible Things
# 6   762975                                  Purple Hearts
# 7      129                                  Spirited Away
# 8   372754                       Dou kyu sei – Classmates
# 9   372058                                     Your Name.
# 10  730154                                 Your Eyes Tell
# 11     389                                   12 Angry Men
# 12  696374                              Gabriel's Inferno
# 13  496243                                       Parasite
# 14     497                                 The Green Mile
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,5):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c5bc87518260a2911807fb0ab754193d&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_7812\1290007807.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_7812\1290007807.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_7812\1290007807.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_7812\1290007807.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#            id                               title  \
# 0       19404         Dilwale Dulhania Le Jayenge
# 1         278            The Shawshank Redemption
# 2         238                       The Godfather
# 3         424                    Schindler's List
# 4         240              The Godfather: Part II
# ...       ...                                 ...
# 10155  618344  Justice League Dark: Apokolips War
# 10156     105                  Back to the Future
# 10157     975                      Paths of Glory
# 10158   15804               A Brighter Summer Day
# 10159  447362                      Life in a Year
#
#                                                 overview release_date  \
# 0      Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.shape
# Out:
# (10160, 7)

# %%
df.to_csv('movies.csv')

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/mrsud/Documents/Python code/counties.csv")

# %%
df
# Out:
#        fips country state                      county   level  lat  \
# 0      2013      US    AK      Aleutians East Borough  county  NaN
# 1      2016      US    AK  Aleutians West Census Area  county  NaN
# 2      2020      US    AK      Anchorage Municipality  county  NaN
# 3      2050      US    AK          Bethel Census Area  county  NaN
# 4      2060      US    AK         Bristol Bay Borough  county  NaN
# ...     ...     ...   ...                         ...     ...  ...
# 3218  56037      US    WY           Sweetwater County  county  NaN
# 3219  56039      US    WY                Teton County  county  NaN
# 3220  56041      US    WY                Uinta County  county  NaN
# 3221  56043      US    WY             Washakie County  county  NaN
# 3222  56045      US    WY               Weston County  county  NaN
#
#                          locationId  long  population  \
# 0     iso1:us#iso2:us-ak#fips:02013   NaN        3337
# ...

# %%
df=pd.read_csv('C:\\Users\\mrsud\\Documents\\Python code\\counties.csv')

# %%
df
# Out:
#        fips country state                      county   level  lat  \
# 0      2013      US    AK      Aleutians East Borough  county  NaN
# 1      2016      US    AK  Aleutians West Census Area  county  NaN
# 2      2020      US    AK      Anchorage Municipality  county  NaN
# 3      2050      US    AK          Bethel Census Area  county  NaN
# 4      2060      US    AK         Bristol Bay Borough  county  NaN
# ...     ...     ...   ...                         ...     ...  ...
# 3218  56037      US    WY           Sweetwater County  county  NaN
# 3219  56039      US    WY                Teton County  county  NaN
# 3220  56041      US    WY                Uinta County  county  NaN
# 3221  56043      US    WY             Washakie County  county  NaN
# 3222  56045      US    WY               Weston County  county  NaN
#
#                          locationId  long  population  \
# 0     iso1:us#iso2:us-ak#fips:02013   NaN        3337
# ...

# %%
df['popularity'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'popularity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['population'].max()
# Out:
# 10039107

# %%
df['population'][df['population']=='18386']
# Out:
# Series([], Name: population, dtype: int64)

# %%
df['population'][df['population']==18386]
# Out:
# 3      18386
# 387    18386
# Name: population, dtype: int64

# %%
df=pd.read_csv('')
