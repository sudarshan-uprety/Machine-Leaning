# %%
import pandas as pd
df=pd.read_csv('weather_data.csv')

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows, columns=df.shape

# %%
columns
# Out:
# 4

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
df[0:7]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[['day','temperature']][df.temperature==df.temperature.max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df[5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df=df.set_index('day')

# %%
df.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.reset_index()
# Out:
#    index  temperature  windspeed
# 0      0           32          6
# 1      1           35          7
# 2      2           28          2
# 3      3           24          7
# 4      4           32          4
# 5      5           31          2

# %%
df
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
df=df.set_index('temperature',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 df=df.set_index('temperature',inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# ...

# %%
df
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of              windspeed
# temperature
# 32                   6
# 35                   7
# 28                   2
# 24                   7
# 32                   4
# 31                   2>

# %%
df
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 pd.DataFrame.reset_index()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: reset_index() missing 1 required positional argument: 'self'

# %%
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
df
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#    temperature  windspeed
# 0           32          6
# 1           35          7
# 2           28          2
# 3           24          7
# 4           32          4
# 5           31          2

# %%
df.drop('event', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 df.drop('event', axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#    level_0  index  temperature  windspeed
# 0        0      0           32          6
# 1        1      1           35          7
# 2        2      2           28          2
# 3        3      3           24          7
# 4        4      4           32          4
# 5        5      5           31          2

# %%
df
# Out:
#    index  temperature  windspeed
# 0      0           32          6
# 1      1           35          7
# 2      2           28          2
# 3      3           24          7
# 4      4           32          4
# 5      5           31          2

# %%
df
# Out:
#    level_0  index  temperature  windspeed
# 0        0      0           32          6
# 1        1      1           35          7
# 2        2      2           28          2
# 3        3      3           24          7
# 4        4      4           32          4
# 5        5      5           31          2

# %%
df=pd.read_csv('weather_data.csv')

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.loc['Snow']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 df.loc['Snow']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# ...

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %% [markdown]
# # DATA FRAME IN PANDAS

# %%
import pandas as pd

df=pd.read_csv('weather_data.csv')

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data_from_dictinoary={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','snow','Rain','Sunny']
}

# %%
weather_data_from_dictionary
# Out:
# {'day': ['1/1/2017',
#   '1/2/2017',
#   '1/3/2017',
#   '1/4/2017',
#   '1/5/2017',
#   '1/6/2017'],
#  'temperature': [32, 35, 28, 24, 32, 31],
#  'windspeed': [6, 7, 2, 7, 4, 2],
#  'event': ['Rain', 'Sunny', 'Snow', 'snow', 'Rain', 'Sunny']}

# %%
pd.DataFrame(weather_data_from_dictinoary)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df1=pd.DataFrame(weather_data_from_dictinoary)

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
import csv

# %%
df2=pd.DataFrame.from_dict(df1)

# %%
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df2.to_csv('weather_data_from_dictionary.csv',index=False)

# %%
df3=pd.read_csv('weather_data_from_dictionary.csv')

# %%
df3
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df={
   "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": 28,
   "address": {
       "streetAddress": "101",
       "city": "San Diego",
       "state": "CA"
   },
   "phoneNumbers": [
       { "type": "home", "number": "7349282382" }
   ]
}

# %%
df
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
df.to_csv('json_file_to_csv_file.csv',index=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 df.to_csv('json_file_to_csv_file.csv',index=None)
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
df
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
df=pd.read_json('json_file.json',orient='index')

# %%
df
# Out:
#                                                               0
# firstName                                                   Joe
# lastName                                                Jackson
# gender                                                     male
# age                                                          28
# address       {'streetAddress': '101', 'city': 'San Diego', ...
# phoneNumbers         [{'type': 'home', 'number': '7349282382'}]

# %%
df.to_csv('json_file_to_csv.csv')

# %% [markdown]
# # WORKING WITH EXCEL FILE

# %%
import pandas as pd
df=pd.read_csv("stock_data.csv",na_values=['not available','n.a.'])

# %%
df
# Out:
#   ticker    eps  revenue   price         people
# 0  GOOGL  27.82       87   845.0     larry page
# 1    WMT   4.61      484    65.0            NaN
# 2   MSFT  -1.00       85    64.0     bill gates
# 3   RIL     NaN       50  1023.0  mukesh ambani
# 4   TATA   5.60       -1     NaN     ratan tata

# %%
df.head(3)
# Out:
#   ticker    eps  revenue price      people
# 0  GOOGL  27.82       87   845  larry page
# 1    WMT   4.61      484    65        n.a.
# 2   MSFT     -1       85    64  bill gates

# %%
df
# Out:
#   ticker            eps  revenue price         people
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
df.na_values=["not available","n.a."]
# Out:
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_15804\2536483246.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.na_values=["not available","n.a."]

# %%
df
# Out:
#   ticker            eps  revenue price         people
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
df.pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [173], in <cell line: 1>()
# ----> 1 df.pd
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
df
# Out:
#   ticker    eps  revenue   price         people
# 0  GOOGL  27.82       87   845.0     larry page
# 1    WMT   4.61      484    65.0            NaN
# 2   MSFT  -1.00       85    64.0     bill gates
# 3   RIL     NaN       50  1023.0  mukesh ambani
# 4   TATA   5.60       -1     NaN     ratan tata

# %%
df1=pd.read_csv("stock_data.csv",na_values={
    'eps':['not available','n.a.'],
    'revenue':['not available','n.a.',-1],
    'people':['not available','n.a.'],
    'price':['not available','n.a.']
})

# %%
df1
# Out:
#   ticker    eps  revenue   price         people
# 0  GOOGL  27.82     87.0   845.0     larry page
# 1    WMT   4.61    484.0    65.0            NaN
# 2   MSFT  -1.00     85.0    64.0     bill gates
# 3   RIL     NaN     50.0  1023.0  mukesh ambani
# 4   TATA   5.60      NaN     NaN     ratan tata

# %%
df1.to_csv('cleaned_csv_stock_data_file.csv',index=False)

# %%
df1.columns
# Out:
# Index(['ticker', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %% [markdown]
# # WORKING WITH EXCEL FILE

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'sam walton'
    return cell
def convert_eps_cell(cell):
    if cell=="not available":
        return "NaN"
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return "NaN"
    return cell

df=pd.read_excel('stock_data.xlsx',converters={
    'people':convert_people_cell,
    'eps':convert_eps_cell,
    'price':convert_price_cell
})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65     sam walton
# 2    MSFT     -1       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA    5.6       -1   NaN     ratan tata

# %%
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df.to_excel('cleaned_excel_stock_data_file.xlsx',index=False)

# %%
df1=pd.read_excel('stock_data.xlsx')

# %%
df1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65     sam walton
# 2    MSFT     -1       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA    5.6       -1   NaN     ratan tata

# %%
df1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
with pd.ExcelWriter('writing_2_data_to_same_excel_file.xlsx') as writer:
    df1.to_excel(writer,sheet_name='uncleaned data',index=False)
    df.to_excel(writer,sheet_name='cleaned data',index=False)

# %% [markdown]
# # HANDLING THE MISSING DATA

# %%
import pandas as pd
df=pd.read_csv('missing_weather_data.csv')
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
import pandas as pd
df=pd.read_csv('missing_weather_data.csv',parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
import pandas as pd
df=pd.read_csv('missing_weather_data.csv',parse_dates=['day'])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'no event'
})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_df=df.fillna(method="ffill", limit=3) #can also use "nfill" for backward fill
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.interpolate(method="time")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","01-11-2017") #using pd.date_range function to give where date start and when ends
idx=pd.DatetimeIndex(dt) #using idx variable to put DateTimeIndex and passing the dt variable
df=df.reindex(idx) #finally reindexing the idx and assigning all the values to df
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df=df.interpolate()

# %%
df
# Out:
#             temperature  windspeed   event
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-02    31.000000       7.00     NaN
# 2017-01-03    30.000000       8.00     NaN
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
df=df.fillna(method='ffill')
df
# Out:
#             temperature  windspeed   event
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-02    31.000000       7.00    Rain
# 2017-01-03    30.000000       8.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00    Snow
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75   Sunny
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-02    31.000000       7.00    Rain
# 2017-01-03    30.000000       8.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00    Snow
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75   Sunny
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
df.to_csv('cleaned_weather_data_using_pandas.csv')

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('weather_data_with_wrong_infos.csv')
df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017        32 F     6 mph      Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017        28 C    -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34     5 mph         0

# %%
new_df=df.replace(-99999,np.NaN)
new_df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017        32 F     6 mph      Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017        28 C    -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34     5 mph         0

# %%
new_df=df.replace({
    'temperature':-99999,
    'windspeed':[-99999,-88888],
    'event':['0']
},np.NaN)

# %%
new_df
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          NaN        7.0     Sunny
# 2  1/3/2017         28.0        NaN      Snow
# 3  1/4/2017          NaN        7.0       NaN
# 4  1/5/2017         32.0        NaN      Rain
# 5  1/6/2017         31.0        2.0  no event
# 6  1/6/2017         34.0        5.0       NaN

# %%
new_df=df.replace({
    -99999:np.NaN,
    'no event':'sunny',
    '0':np.NaN
})
new_df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017        32 F     6 mph   Rain
# 1  1/2/2017      -99999         7  Sunny
# 2  1/3/2017        28 C    -99999   Snow
# 3  1/4/2017      -99999         7    NaN
# 4  1/5/2017          32    -88888   Rain
# 5  1/6/2017          31         2  sunny
# 6  1/6/2017          34     5 mph    NaN

# %%
new_df=df.replace({
    '-99999':np.NaN,
    'no event':'sunny',
    '0':np.NaN,
    '-88888': np.NaN
})
new_df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017        32 F     6 mph   Rain
# 1  1/2/2017         NaN         7  Sunny
# 2  1/3/2017        28 C       NaN   Snow
# 3  1/4/2017         NaN         7    NaN
# 4  1/5/2017          32       NaN   Rain
# 5  1/6/2017          31         2  sunny
# 6  1/6/2017          34     5 mph    NaN

# %%
new_df=df.replace({
    'temperature':'[A-Za-z]',
    'windspeed':'[A-Za-z]',
    '-99999':np.NaN,
    'no event':'sunny'
},'',regex=True)

new_df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017         32         6       Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017         28     -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34        5          0

# %%
new_df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017         32         6       Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017         28     -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34        5          0

# %%
new_df=new_df.replace({
    'no event':'sunny',
    '-99999':np.NaN,
    '-88888':np.NaN
    
})
new_df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017         32         6    Rain
# 1  1/2/2017         NaN         7  Sunny
# 2  1/3/2017         28        NaN   Snow
# 3  1/4/2017         NaN         7      0
# 4  1/5/2017          32       NaN   Rain
# 5  1/6/2017          31         2  sunny
# 6  1/6/2017          34        5       0

# %%
new_df=new_df

# %%
new_df=new_df.set_index('day')

# %%
dt=pd.date_range('01-01-2017','01-11-2017')
idx=pd.DatetimeIndex(dt)
new_df=new_df.reindex(idx)
new_df
# Out:
#             day temperature windspeed event
# 2017-01-01  NaN         NaN       NaN   NaN
# 2017-01-02  NaN         NaN       NaN   NaN
# 2017-01-03  NaN         NaN       NaN   NaN
# 2017-01-04  NaN         NaN       NaN   NaN
# 2017-01-05  NaN         NaN       NaN   NaN
# 2017-01-06  NaN         NaN       NaN   NaN
# 2017-01-07  NaN         NaN       NaN   NaN
# 2017-01-08  NaN         NaN       NaN   NaN
# 2017-01-09  NaN         NaN       NaN   NaN
# 2017-01-10  NaN         NaN       NaN   NaN
# 2017-01-11  NaN         NaN       NaN   NaN

# %%
new_df=df
df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017        32 F     6 mph      Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017        28 C    -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34     5 mph         0

# %%
new_df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017        32 F     6 mph      Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017        28 C    -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34     5 mph         0

# %%
new_df=new_df.set_index('day')

# %%
new_df
# Out:
#          temperature windspeed     event
# day
# 1/1/2017        32 F     6 mph      Rain
# 1/2/2017      -99999         7     Sunny
# 1/3/2017        28 C    -99999      Snow
# 1/4/2017      -99999         7         0
# 1/5/2017          32    -88888      Rain
# 1/6/2017          31         2  no event
# 1/6/2017          34     5 mph         0

# %%
new_df=pd.date_range('01-01-2017','01-11-2017')

# %%
new_df=df
new_df=new_df.set_index('day')
new_df
# Out:
#          temperature windspeed     event
# day
# 1/1/2017        32 F     6 mph      Rain
# 1/2/2017      -99999         7     Sunny
# 1/3/2017        28 C    -99999      Snow
# 1/4/2017      -99999         7         0
# 1/5/2017          32    -88888      Rain
# 1/6/2017          31         2  no event
# 1/6/2017          34     5 mph         0

# %%
new_df
# Out:
#          temperature windspeed     event
# day
# 1/1/2017        32 F     6 mph      Rain
# 1/2/2017      -99999         7     Sunny
# 1/3/2017        28 C    -99999      Snow
# 1/4/2017      -99999         7         0
# 1/5/2017          32    -88888      Rain
# 1/6/2017          31         2  no event
# 1/6/2017          34     5 mph         0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [168], in <cell line: 2>()
#       1 idx = pd.period_range(min(df.day), max(df.day))
# ----> 2 idx=results.reindex(idx, fill_value=0)
#
# NameError: name 'results' is not defined

# %%
new_df
# Out:
#          temperature windspeed     event
# day
# 1/1/2017        32 F     6 mph      Rain
# 1/2/2017      -99999         7     Sunny
# 1/3/2017        28 C    -99999      Snow
# 1/4/2017      -99999         7         0
# 1/5/2017          32    -88888      Rain
# 1/6/2017          31         2  no event
# 1/6/2017          34     5 mph         0

# %%
new_df=pd.read_csv('weather_data_with_wrong_infos.csv')
new_df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
new_df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
dt=pd.date_range('01-01-2017','01-16-2017')
idx=pd.DatetimeIndex(dt)
df.reindex(idx)
df
# Out:
#         day temperature windspeed     event
# 0  1/1/2017        32 F     6 mph      Rain
# 1  1/2/2017      -99999         7     Sunny
# 2  1/3/2017        28 C    -99999      Snow
# 3  1/4/2017      -99999         7         0
# 4  1/5/2017          32    -88888      Rain
# 5  1/6/2017          31         2  no event
# 6  1/6/2017          34     5 mph         0

# %%
new_df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
new_df=pd.date_range('01-01-2017','01-16-2017')
idx=pd.DatetimeIndex(new_df)
df1.reindex(idx)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [182], in <cell line: 3>()
#       1 new_df=pd.date_range('01-01-2017','01-16-2017')
#       2 idx=pd.DatetimeIndex(new_df)
# ----> 3 df1.reindex(idx)
#       4 df1
#
# NameError: name 'df1' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv('weather_data_with_wrong_infos.csv')
df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
df=df.set_index('day')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df=df.set_index('day')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# ...

# %%
df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
df=pd.read_csv('weather_data_with_wrong_infos.csv')
df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
df=df.set_index('day')

# %%
df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
df
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.read_csv('weather_data_with_wrong_infos.csv')
df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
df=df.set_index('day')

# %%
df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
dr=pd.date_range('01-01-2017','01-16-2017')
idx=pd.DatetimeIndex(dr)
df=df.reindex(idx)
df
# Out:
#            temperature windspeed event
# 2017-01-01         NaN       NaN   NaN
# 2017-01-02         NaN       NaN   NaN
# 2017-01-03         NaN       NaN   NaN
# 2017-01-04         NaN       NaN   NaN
# 2017-01-05         NaN       NaN   NaN
# 2017-01-06         NaN       NaN   NaN
# 2017-01-07         NaN       NaN   NaN
# 2017-01-08         NaN       NaN   NaN
# 2017-01-09         NaN       NaN   NaN
# 2017-01-10         NaN       NaN   NaN
# 2017-01-11         NaN       NaN   NaN
# 2017-01-12         NaN       NaN   NaN
# 2017-01-13         NaN       NaN   NaN
# 2017-01-14         NaN       NaN   NaN
# 2017-01-15         NaN       NaN   NaN
# 2017-01-16         NaN       NaN   NaN

# %%
df=pd.read_csv('weather_data_with_wrong_infos.csv')
df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
new_df=df

# %%
new_df
# Out:
#          day temperature windspeed     event
# 0   1/1/2017        32 F     6 mph      Rain
# 1   1/4/2017      -99999         7     Sunny
# 2   1/6/2017        28 C    -99999      Snow
# 3   1/9/2017      -99999         7         0
# 4  1/10/2017          32    -88888      Rain
# 5  1/11/2017          31         2  no event
# 6  1/16/2017          34     5 mph         0

# %%
new_df=df.set_index('day')

# %%
new_df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
new_df
# Out:
#           temperature windspeed     event
# day
# 1/1/2017         32 F     6 mph      Rain
# 1/4/2017       -99999         7     Sunny
# 1/6/2017         28 C    -99999      Snow
# 1/9/2017       -99999         7         0
# 1/10/2017          32    -88888      Rain
# 1/11/2017          31         2  no event
# 1/16/2017          34     5 mph         0

# %%
dr=pd.date_range('01-01-2017','01-16-2017')
idx=pd.DatetimeIndex(dr)
new_df=new_df.reindex(idx)
new_df
# Out:
#            temperature windspeed event
# 2017-01-01         NaN       NaN   NaN
# 2017-01-02         NaN       NaN   NaN
# 2017-01-03         NaN       NaN   NaN
# 2017-01-04         NaN       NaN   NaN
# 2017-01-05         NaN       NaN   NaN
# 2017-01-06         NaN       NaN   NaN
# 2017-01-07         NaN       NaN   NaN
# 2017-01-08         NaN       NaN   NaN
# 2017-01-09         NaN       NaN   NaN
# 2017-01-10         NaN       NaN   NaN
# 2017-01-11         NaN       NaN   NaN
# 2017-01-12         NaN       NaN   NaN
# 2017-01-13         NaN       NaN   NaN
# 2017-01-14         NaN       NaN   NaN
# 2017-01-15         NaN       NaN   NaN
# 2017-01-16         NaN       NaN   NaN

# %%
new_df.to_csv('1.csv')

# %% [markdown]
# # USING GROUP BY in Pandas

# %%
df=pd.read_csv('weather_by_cities.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g

# %%
 print(g)

# %%
for city , city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
for city_name,city_data in g:
    print(city_name)
    print(city_data)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean('windspeed')
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %% [markdown]
# # CONACT IN PANDAS

# %%
import pandas as pd

india_weather=pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temperature':[32,45,30],
    'humidity':[80,60,78]
})

india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather=pd.DataFrame({
    'city':['new york','chicago','orlando'],
    'temperature':[21,14,35],
    'humidity':[69,65,75]
})

us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        69
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        69
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df.keys=['india','usa']

# %%
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        69
# 4   chicago           14        65
# 5   orlando           35        75

# %%
temprature_df=pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temperature':[32,45,30],

}, index=[0,1,2])
    


temprature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df=pd.DataFrame({
     'city':['delhi','mumbai'],
    'windspeed':[6,12]
},index=[1,0])

windspeed_df
# Out:
#      city  windspeed
# 1   delhi          6
# 0  mumbai         12

# %%
df=pd.concat([temprature_df,windspeed_df],axis=1)

# %%
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        6.0
# 2  banglore           30     NaN        NaN

# %%
temprature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
s=pd.Series(['humid','dry','rain'],name="event")
s
# Out:
# 0    humid
# 1      dry
# 2     rain
# Name: event, dtype: object

# %%
df=pd.concat([temprature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  humid
# 1     delhi           45    dry
# 2  banglore           30   rain

# %%
df1=pd.DataFrame({
    'city':['new york','chicago','orlendo','baltimor'],
    'temperature':[21,14,35,23]
})

df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlendo           35
# 3  baltimor           23

# %%
df2=pd.DataFrame({
    'city':['chicago','new york','san franscico'],
    'humidity':[60,68,54]
})
df2
# Out:
#             city  humidity
# 0        chicago        60
# 1       new york        68
# 2  san franscico        54

# %%
df=pd.merge(df1,df2,on='city',how='outer',indicator=True)
df
# Out:
#             city  temperature  humidity      _merge
# 0       new york         21.0      68.0        both
# 1        chicago         14.0      60.0        both
# 2        orlendo         35.0       NaN   left_only
# 3       baltimor         23.0       NaN   left_only
# 4  san franscico          NaN      54.0  right_only

# %%
df1=pd.DataFrame({
    'city':['new york','chicago','orlando','baltimore'],
    'temperature':[21,14,35,38],
    'humidity':[65,68,71,75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2=pd.DataFrame({
    'city':['chicago','new york','sandiago'],
    'temperature':[21,14,35],
    'humidity':[65,68,71]
})
df2
# Out:
#        city  temperature  humidity
# 0   chicago           21        65
# 1  new york           14        68
# 2  sandiago           35        71

# %%
pd.merge(df1,df2,on='city',suffixes=('_left','_right'))
# Out:
#        city  temperature_left  humidity_left  temperature_right  \
# 0  new york                21             65                 14
# 1   chicago                14             68                 21
#
#    humidity_right
# 0              68
# 1              65

# %% [markdown]
# # PIVOT IN PANDAS

# %%
df=pd.read_csv('weather_data_for_pivot.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df=pd.read_csv('weather2.csv')

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='city',columns='date',margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df=pd.read_csv('weather3.csv')
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df['date']=pd.to_datetime(df['date'])

df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# # MELT IN PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv('weather_data_for_melt.csv')

# %%
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df1=pd.melt(df,id_vars=["day"],var_name="city",value_name="temperature")
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# # STACK IN PANDAS

# %%
import pandas as pd
df=pd.read_excel('stocks.xlsx',header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack()
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
df=pd.read_excel('stocks.xlsx',header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack(level=0)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
df2=pd.read_excel('stocks_3_levels.xlsx',header=[0,1,2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df2.stack()
# Out:
#             Income Statement           Price Ratios  \
#                   Net Profit Net Sales        Price
# 0 Company                NaN       NaN          NaN
#   Facebook              0.80      2.60        155.0
#   Google                5.43     20.00        955.0
#   Microsoft             4.56     18.70         66.0
# 1 Company                NaN       NaN          NaN
#   Facebook              0.97      3.10        150.0
#   Google                5.89     22.00        987.0
#   Microsoft             5.10     21.30         69.0
# 2 Company                NaN       NaN          NaN
#   Facebook              1.20      4.30        153.0
#   Google                6.10     24.00        963.0
#   Microsoft             5.43     21.45         62.0
# 3 Company                NaN       NaN          NaN
#   Facebook              1.67      6.70        155.0
#   Google                6.50     26.00       1000.0
#   Microsoft             5.89     21.88         61.0
# ...

# %% [markdown]
# # Crosstab IN PANDAS

# %%
import pandas as pd
import numpy as np
df=pd.read_excel('survey.xls')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab([df.Sex],[df.Handedness],values=df.Age,aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
#  # READING AND WRITING FROM DATABASE

# %%
import pandas as pd
import sqlalchemy

# %%
engine=sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/machinelearning')

# %%
pip install pymysql
# Out:
# ...
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_sql_table('customer',engine,columns=['name','phone_number'])

# %%
df
# Out:
#         name phone_number
# 0  sudarshan   9845928699
# 1       hari   9845928700
# 2        ram   9845928701
# 3       sita   9845928702

# %%
query='''
SELECT customer.name,customer.phone_number,orders.name,orders.amount
 FROM customer INNER JOIN orders
 ON customer.id=orders.customer_id
'''
df=pd.read_sql_query(query,engine)
df
# Out:
#         name phone_number          name  amount
# 0       hari   9845928700      yoga mat     300
# 1        ram   9845928701  google pixel   35000
# 2  sudarshan   9845928699         watch    5000
# 3       sita   9845928702   tooth brush      50

# %%
df= pd.read_csv('customer.csv')
df
# Out:
#      customer name  customer phone
# 0           rafael      4563245678
# 1   mari sharapova      4323764567
# 2  valadimir putin      3478282433
# 3      kim un jong      7652452672
# 4       jeff vezos      9853425627
# 5     rahul gandhi      4321234567

# %%
df.rename(columns={
    'customer name':'name',
    'customer phone':'phone_number'
},inplace=True)
df
# Out:
#               name  phone_number
# 0           rafael    4563245678
# 1   mari sharapova    4323764567
# 2  valadimir putin    3478282433
# 3      kim un jong    7652452672
# 4       jeff vezos    9853425627
# 5     rahul gandhi    4321234567

# %%
df.to_sql(
    'customer',
    con=engine,
    index=False,
    if_exists='append'
)
# Out:
# 6

# %%
pd.read_sql('customer',engine)
# Out:
#    id             name phone_number
# 0   1        sudarshan   9845928699
# 1   2             hari   9845928700
# 2   3              ram   9845928701
# 3   4             sita   9845928702
# 4   5           rafael   4563245678
# 5   6   mari sharapova   4323764567
# 6   7  valadimir putin   3478282433
# 7   8      kim un jong   7652452672
# 8   9       jeff vezos   9853425627
# 9  10     rahul gandhi   4321234567

# %%
query='''
SELECT customer.name,customer.phone_number,orders.name,orders.amount
 FROM customer INNER JOIN orders
 ON customer.id=orders.customer_id
'''
pd.read_sql(query,engine)
# Out:
#         name phone_number          name  amount
# 0       hari   9845928700      yoga mat     300
# 1        ram   9845928701  google pixel   35000
# 2  sudarshan   9845928699         watch    5000
# 3       sita   9845928702   tooth brush      50

# %% [markdown]
# # TIME SERIES IN PANDAS PART 1

# %%
import pandas as pd
df=pd.read_csv('apple.csv',parse_dates=['Date'],index_col="Date")
df.head(5)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["2017-01-07":"2017-01-01"]
# Out:
# C:\Users\mrsud\AppData\Local\Temp\ipykernel_19040\2466638625.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df["2017-01-07":"2017-01-01"]
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
# %matplotlib inline
df.Close.resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # TIME SERIES PART 2

# %%
import pandas as pd
df=pd.read_csv('aapl_no_dates.csv')

# %%
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
rng=pd.date_range(start='6/1/2017',end='6/30/2017',freq='B ')
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df['2017-06-01':'2017-06-10'].Close.plot()
# Out:
# <AxesSubplot:>

# %%
df['2017-06-01':'2017-06-10'].Close.mean()
# Out:
# 153.7642857142857

# %%
df.asfreq('D')
# Out:
#               Open    High     Low   Close      Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088.0
# 2017-06-02  153.58  155.45  152.89  155.45  27770715.0
# 2017-06-03     NaN     NaN     NaN     NaN         NaN
# 2017-06-04     NaN     NaN     NaN     NaN         NaN
# 2017-06-05  154.34  154.45  153.46  153.93  25331662.0
# 2017-06-06  153.90  155.81  153.78  154.45  26624926.0
# 2017-06-07  155.02  155.98  154.48  155.37  21069647.0
# 2017-06-08  155.25  155.54  154.40  154.99  21250798.0
# 2017-06-09  155.19  155.19  146.02  148.98  64882657.0
# 2017-06-10     NaN     NaN     NaN     NaN         NaN
# 2017-06-11     NaN     NaN     NaN     NaN         NaN
# 2017-06-12  145.74  146.09  142.51  145.42  72307330.0
# 2017-06-13  147.16  147.45  145.15  146.59  34165445.0
# 2017-06-14  147.50  147.50  143.84  145.16  31531232.0
# 2017-06-15  143.32  144.48  142.21  144.29  32165373.0
# 2017-06-16  143.78  144.50  142.20  142.27  50361093.0
# ...

# %%
df.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
rng=pd.date_range(start='1/1/2017',periods=72,freq='H')
rng
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                '2017-01-01 10:00:00', '2017-01-01 11:00:00',
#                '2017-01-01 12:00:00', '2017-01-01 13:00:00',
#                '2017-01-01 14:00:00', '2017-01-01 15:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 17:00:00',
#                '2017-01-01 18:00:00', '2017-01-01 19:00:00',
#                '2017-01-01 20:00:00', '2017-01-01 21:00:00',
#                '2017-01-01 22:00:00', '2017-01-01 23:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 01:00:00',
#                '2017-01-02 02:00:00', '2017-01-02 03:00:00',
#                '2017-01-02 04:00:00', '2017-01-02 05:00:00',
# ...

# %%
import numpy as np
np.random.randint(1,10,len(rng))
# Out:
# array([2, 9, 3, 9, 3, 9, 2, 1, 2, 2, 9, 8, 6, 1, 8, 8, 7, 1, 5, 5, 4, 1,
#        6, 8, 7, 2, 1, 1, 9, 4, 3, 2, 3, 5, 6, 5, 8, 9, 8, 8, 9, 9, 7, 3,
#        2, 1, 5, 5, 8, 7, 7, 4, 8, 4, 8, 1, 8, 4, 7, 5, 3, 9, 5, 7, 2, 6,
#        9, 8, 9, 3, 5, 7])

# %%
ts=pd.Series
